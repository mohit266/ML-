# %%
import sys
import cv2
from google.colab.patches import cv2_imshow

# %%
cv2.__version__
# Out:
# '3.4.3'

# %%
# image name as first argu
dog = sys.argv[1]

# %%
# image read
img = cv2.imread('dog.jpg',1)   # loading image in a colored format -- original image
img

# %%
cv2_imshow(img)
cv2_imshow(img-50)
cv2_imshow(img+100)
# Out:
# <PIL.Image.Image image mode=RGB size=1080x447 at 0x7FB34E54B1D0>
# <PIL.Image.Image image mode=RGB size=1080x447 at 0x7FB34E54B2B0>
# <PIL.Image.Image image mode=RGB size=1080x447 at 0x7FB34E54B198>

# %%
# saving image
cv2.imwrite('new.jpg',img)
# Out:
# True
