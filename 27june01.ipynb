# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url='https://en.wikipedia.org/wiki/Portal:Science'

# %%
# we are sending request to the url and taking the response
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Portal:Science - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"Portal","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":100,"wgPageName":"Portal:Science","wgTitle":"Science","wgCurRevisionId":898554272,"wgRevisionId":898554272,"wgArticleId":1855835,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Manually maintained portal pages from June 2018","All manually maintained portal pages","Portals with untriaged subpages from June 2018","All portals with untriaged subpages","All portals","Portals with named maintainer","Portals with short description","Wikipedia semi-protected portals","Random portal component with 21–25 available subpages","Random portal component with 16–20 available imag
# ...

# %%
# parsing library - html and second is lxml
soup=BeautifulSoup(response.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Portal:Science - Wikipedia</title>
# ...

# %%
for alink in soup.find_all('a'):
  print(alink.get('href'))
# Out:
# None
# /wiki/Wikipedia:Featured_portals
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/File:Darkgreen_flag_waving.svg
# /wiki/Wikipedia:WikiProject_Portals#Specific_portal_maintainers
# /wiki/User:Ancheta_Wis
# /wiki/Special:PrefixIndex/Portal:Science/
# /wiki/Wikipedia_talk:WikiProject_Portals/Tasks#Requests_for_Admin_assistance
# /wiki/Wikipedia:CAREFUL
# /wiki/Wikipedia:ASSISTED
# /wiki/Wikipedia:Consensus
# /wiki/Template:Portal_maintenance_status#How_to_update_the_maintenance_information_for_a_portal
# /wiki/Portal:Contents/Portals
# /wiki/Portal:Contents/Portals#Human_activities
# /wiki/Portal:Contents/Portals#Culture_and_the_arts
# /wiki/Portal:Contents/Portals#Geography_and_places
# /wiki/Portal:Contents/Portals#Health_and_fitness
# /wiki/Portal:Contents/Portals#History_and_events
# /wiki/Portal:Contents/Portals#Mathematics_and_logic
# /wiki/Portal:Contents/Portals#Natural_and_physical_sciences
# /wiki/Portal:Contents/Portals#People_and_self
# ...

# %%
for ptag in soup.find_all('p'):
  print(ptag)
  # now second loop for b tag
  for btag in ptag.find_all('b'):
    print(btag.text)
# Out:
# <p class="mw-empty-elt">
# </p>
# <p><br/>
# </p>
# <p><a class="image" href="/wiki/File:PrirodneNauke.svg" title="Applied science"><img alt="Applied science" data-file-height="128" data-file-width="128" decoding="async" height="100" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/ae/PrirodneNauke.svg/100px-PrirodneNauke.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/ae/PrirodneNauke.svg/150px-PrirodneNauke.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/ae/PrirodneNauke.svg/200px-PrirodneNauke.svg.png 2x" width="100"/></a><br/>
# </p>
# ...
